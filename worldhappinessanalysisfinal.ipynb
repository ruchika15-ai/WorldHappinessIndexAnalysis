# %% [markdown]
# **A. Importing, cleaning and numerical summaries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
WHR = pd.read_csv("C:\\Users\\Khushi\\Downloads\\World-Happiness-Report-Data-Analysis-master\\World-Happiness-Report-Data-Analysis-master\\2024.csv")
WHR
# Out:
#          Country name  Happiness Rank  Happiness Score   Economy    Family  \
# 0             Finland               1            7.537  1.616463  1.533524
# 1             Denmark               2            7.522  1.482383  1.551122
# 2             Iceland               3            7.504  1.480633  1.610574
# 3              Sweden               4            7.494  1.564980  1.516912
# 4              Israel               5            7.469  1.443572  1.540247
# ..                ...             ...              ...       ...       ...
# 138  Congo (Kinshasa)             141            3.794  0.401477  0.581543
# 139      Sierra Leone             142            3.766  1.122094  1.221555
# 140           Lesotho             143            3.657  0.431085  0.435300
# 141           Lebanon             144            3.644  0.305809  0.913020
# 142       Afghanistan             145            3.603  0.368610  0.640450
#
#        Health   Freedom  Generosity  Corruption  Dystopia  Job Satisfaction  \
# 0    0.796667  0.635423    0.362012    0.315964  2.277027              94.6
# 1    0.792566  0.626007    0.355280    0.400770  2.313707              93.5
# 2    0.833552  0.627163    0.475540    0.153527  2.322715              94.5
# 3    0.858131  0.620071    0.290549    0.367007  2.276716              93.7
# 4    0.809158  0.617951    0.245483    0.382612  2.430182              91.2
# ..        ...       ...         ...         ...       ...               ...
# 138  0.180747  0.106180    0.311871    0.061158  2.150801              80.0
# 139  0.341756  0.505196    0.099348    0.098583  0.377914              56.1
# 140  0.209930  0.425963    0.207948    0.060929  1.885631              49.3
# 141  0.375223  0.189197    0.208733    0.067232  1.584613              45.3
# 142  0.277321  0.030370    0.489204    0.099872  1.697168              48.5
#
#              Region
# 0    Western Europe
# 1    Western Europe
# 2    Western Europe
# 3    Western Europe
# 4      Asia-Pacific
# ..              ...
# 138    Asia-Pacific
# 139          Africa
# 140          Africa
# 141          Africa
# 142   Latin America
#
# [143 rows x 12 columns]

# %%
WHR.head(10)
# Out:
#   Country name  Happiness Rank  Happiness Score   Economy    Family    Health  \
# 0      Finland               1            7.537  1.616463  1.533524  0.796667
# 1      Denmark               2            7.522  1.482383  1.551122  0.792566
# 2      Iceland               3            7.504  1.480633  1.610574  0.833552
# 3       Sweden               4            7.494  1.564980  1.516912  0.858131
# 4       Israel               5            7.469  1.443572  1.540247  0.809158
# 5  Netherlands               6            7.377  1.503945  1.428939  0.810696
# 6       Norway               7            7.316  1.479204  1.481349  0.834558
# 7   Luxembourg               8            7.314  1.405706  1.548195  0.816760
# 8  Switzerland               9            7.284  1.494387  1.478162  0.830875
# 9    Australia              10            7.284  1.484415  1.510042  0.843887
#
#     Freedom  Generosity  Corruption  Dystopia  Job Satisfaction  \
# 0  0.635423    0.362012    0.315964  2.277027              94.6
# 1  0.626007    0.355280    0.400770  2.313707              93.5
# 2  0.627163    0.475540    0.153527  2.322715              94.5
# 3  0.620071    0.290549    0.367007  2.276716              93.7
# 4  0.617951    0.245483    0.382612  2.430182              91.2
# 5  0.585384    0.470490    0.282662  2.294804              93.8
# 6  0.611101    0.435540    0.287372  2.187264              90.5
# 7  0.614062    0.500005    0.382817  2.046456              88.6
# 8  0.612924    0.385399    0.384399  2.097538              92.7
# 9  0.601607    0.477699    0.301184  2.065211              89.2
#
#            Region
# 0  Western Europe
# 1  Western Europe
# 2  Western Europe
# 3  Western Europe
# 4    Asia-Pacific
# 5  Western Europe
# 6  Western Europe
# 7  Western Europe
# 8  Western Europe
# 9    Asia-Pacific

# %%
WHR.shape
# Out:
# (143, 12)

# %%
print("There are {:,} rows ".format(WHR.shape[0]) + "and {} columns in our data".format(WHR.shape[1]))
# Out:
# There are 143 rows and 12 columns in our data

# %%
WHR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country name      143 non-null    object
#  1   Happiness Rank    143 non-null    int64
#  2   Happiness Score   143 non-null    float64
#  3   Economy           143 non-null    float64
#  4   Family            143 non-null    float64
#  5   Health            143 non-null    float64
#  6   Freedom           143 non-null    float64
#  7   Generosity        143 non-null    float64
#  8   Corruption        143 non-null    float64
#  9   Dystopia          143 non-null    float64
#  10  Job Satisfaction  142 non-null    float64
#  11  Region            143 non-null    object
# dtypes: float64(9), int64(1), object(2)
# memory usage: 13.5+ KB

# %%
WHR.isnull().sum()
# Out:
# Country name        0
# Happiness Rank      0
# Happiness Score     0
# Economy             0
# Family              0
# Health              0
# Freedom             0
# Generosity          0
# Corruption          0
# Dystopia            0
# Job Satisfaction    1
# Region              0
# dtype: int64

# %%
NULLS = WHR[WHR.isnull().any(axis=1)]

# %%
NULLS.head()
# Out:
#    Country name  Happiness Rank  Happiness Score   Economy    Family  \
# 59        China              61             5.81  1.346911  1.186303
#
#       Health   Freedom  Generosity  Corruption  Dystopia  Job Satisfaction  \
# 59  0.834647  0.471204    0.266846    0.155353  1.549158               NaN
#
#             Region
# 59  Eastern Europe

# %%
WHR.dropna(inplace=True)

# %%
WHR.isnull().sum()
# Out:
# Country name        0
# Happiness Rank      0
# Happiness Score     0
# Economy             0
# Family              0
# Health              0
# Freedom             0
# Generosity          0
# Corruption          0
# Dystopia            0
# Job Satisfaction    0
# Region              0
# dtype: int64

# %%
WHR.duplicated().sum()
# Out:
# np.int64(0)

# %%
WHR.describe()
# Out:
#        Happiness Rank  Happiness Score     Economy      Family      Health  \
# count      142.000000       142.000000  142.000000  142.000000  142.000000
# mean        73.197183         5.486134    1.025062    1.223399    0.569202
# std         42.251735         1.040012    0.395204    0.249844    0.229155
# min          1.000000         3.603000    0.022643    0.435300    0.000000
# 25%         37.250000         4.617000    0.748913    1.109118    0.440843
# 50%         73.500000         5.365500    1.080270    1.261384    0.618185
# 75%        109.750000         6.300000    1.324265    1.428153    0.730069
# max        145.000000         7.537000    1.870766    1.610574    0.949492
#
#           Freedom  Generosity  Corruption    Dystopia  Job Satisfaction
# count  142.000000  142.000000  142.000000  142.000000        142.000000
# mean     0.416796    0.243406    0.122948    1.885290         76.369014
# std      0.147288    0.136915    0.101470    0.486405         12.376615
# min      0.000000    0.000000    0.000000    0.377914         44.400000
# 25%      0.310140    0.150603    0.057170    1.617980         70.650000
# 50%      0.445438    0.228482    0.089565    1.847007         79.650000
# 75%      0.520332    0.324529    0.153411    2.184656         85.375000
# max      0.658249    0.838075    0.464308    3.117485         95.100000

# %%
WHR.sort_values(by="Happiness Rank", ascending=True).head(10)
# Out:
#   Country name  Happiness Rank  Happiness Score   Economy    Family    Health  \
# 0      Finland               1            7.537  1.616463  1.533524  0.796667
# 1      Denmark               2            7.522  1.482383  1.551122  0.792566
# 2      Iceland               3            7.504  1.480633  1.610574  0.833552
# 3       Sweden               4            7.494  1.564980  1.516912  0.858131
# 4       Israel               5            7.469  1.443572  1.540247  0.809158
# 5  Netherlands               6            7.377  1.503945  1.428939  0.810696
# 6       Norway               7            7.316  1.479204  1.481349  0.834558
# 7   Luxembourg               8            7.314  1.405706  1.548195  0.816760
# 8  Switzerland               9            7.284  1.494387  1.478162  0.830875
# 9    Australia              10            7.284  1.484415  1.510042  0.843887
#
#     Freedom  Generosity  Corruption  Dystopia  Job Satisfaction  \
# 0  0.635423    0.362012    0.315964  2.277027              94.6
# 1  0.626007    0.355280    0.400770  2.313707              93.5
# 2  0.627163    0.475540    0.153527  2.322715              94.5
# 3  0.620071    0.290549    0.367007  2.276716              93.7
# 4  0.617951    0.245483    0.382612  2.430182              91.2
# 5  0.585384    0.470490    0.282662  2.294804              93.8
# 6  0.611101    0.435540    0.287372  2.187264              90.5
# 7  0.614062    0.500005    0.382817  2.046456              88.6
# 8  0.612924    0.385399    0.384399  2.097538              92.7
# 9  0.601607    0.477699    0.301184  2.065211              89.2
#
#            Region
# 0  Western Europe
# 1  Western Europe
# 2  Western Europe
# 3  Western Europe
# 4    Asia-Pacific
# 5  Western Europe
# 6  Western Europe
# 7  Western Europe
# 8  Western Europe
# 9    Asia-Pacific

# %%
WHR.sort_values(by="Happiness Rank", ascending=False).head(10)
# Out:
#          Country name  Happiness Rank  Happiness Score   Economy    Family  \
# 142       Afghanistan             145            3.603  0.368610  0.640450
# 141           Lebanon             144            3.644  0.305809  0.913020
# 140           Lesotho             143            3.657  0.431085  0.435300
# 139      Sierra Leone             142            3.766  1.122094  1.221555
# 138  Congo (Kinshasa)             141            3.794  0.401477  0.581543
# 137          Zimbabwe             140            3.795  0.858428  1.104412
# 136          Botswana             139            3.808  0.521021  1.190095
# 135            Malawi             138            3.875  0.375847  1.083096
# 134          Eswatini             137            3.936  0.438013  0.953856
# 133            Zambia             136            3.970  0.233442  0.512569
#
#        Health   Freedom  Generosity  Corruption  Dystopia  Job Satisfaction  \
# 142  0.277321  0.030370    0.489204    0.099872  1.697168              48.5
# 141  0.375223  0.189197    0.208733    0.067232  1.584613              45.3
# 140  0.209930  0.425963    0.207948    0.060929  1.885631              49.3
# 139  0.341756  0.505196    0.099348    0.098583  0.377914              56.1
# 138  0.180747  0.106180    0.311871    0.061158  2.150801              80.0
# 137  0.049869  0.000000    0.097926    0.069720  1.614482              71.1
# 136  0.000000  0.390661    0.157497    0.119095  1.429835              44.4
# 135  0.196764  0.336384    0.189143    0.095375  1.597970              56.3
# 134  0.041135  0.162342    0.216114    0.053582  2.071238              67.9
# 133  0.315090  0.466915    0.287170    0.072712  2.081786              51.8
#
#             Region
# 142  Latin America
# 141         Africa
# 140         Africa
# 139         Africa
# 138   Asia-Pacific
# 137         Africa
# 136         Africa
# 135         Africa
# 134         Africa
# 133         Africa

# %% [markdown]
# **B. Indexing and grouping**

# %% [markdown]
# 1.Use the column 'Region' to create a separate DataFrame containing the data points from each of the six regions: North America, Latin America, Western Europe, Eastern Europe, Asia Pacific, Africa.
# 2.Compute the mean happiness score for each region and rank the regions from most happy to least happy.
# 3.Compute the number of countries in each region that have a happiness score above 6.0.
# 4.Compute the difference between the maximum and minimum happiness score for each region. Which region has the largest range of happiness scores?

# %%
WHR_Region = WHR.groupby('Region')

# %%
WHR_Region['Happiness Score'].describe().sort_values(by="mean",ascending=True).head(10)
# Out:
#                 count      mean       std    min     25%    50%     75%    max
# Region
# Europe            1.0  4.096000       NaN  4.096  4.0960  4.096  4.0960  4.096
# Africa           36.0  4.444278  0.558472  3.644  4.0310  4.376  4.7155  5.872
# Asia-Pacific     39.0  5.419974  0.905365  3.794  4.7335  5.269  5.9455  7.469
# Eastern Europe   19.0  5.443000  0.379980  4.644  5.2320  5.395  5.7915  5.973
# Latin America    23.0  5.909739  0.702446  3.603  5.6040  6.008  6.4045  7.079
# North America     2.0  6.793000  0.260215  6.609  6.7010  6.793  6.8850  6.977
# Western Europe   22.0  6.847045  0.594366  5.195  6.5450  6.921  7.3155  7.537

# %%
WHR[WHR["Region"]=="Europe"].head()
# Out:
#     Country name  Happiness Rank  Happiness Score   Economy    Family  \
# 129     Ethiopia             132            4.096  0.894652  1.394538
#
#        Health   Freedom  Generosity  Corruption  Dystopia  Job Satisfaction  \
# 129  0.575904  0.122975    0.270061    0.023029  0.814382              72.3
#
#      Region
# 129  Europe

# %%
WHR = WHR.replace('Europe', 'Eastern Europe')

# %%
WHR_Region['Happiness Score'].describe().sort_values(by="mean",ascending=False).head(10)
# Out:
#                 count      mean       std    min     25%    50%     75%    max
# Region
# Western Europe   22.0  6.847045  0.594366  5.195  6.5450  6.921  7.3155  7.537
# North America     2.0  6.793000  0.260215  6.609  6.7010  6.793  6.8850  6.977
# Latin America    23.0  5.909739  0.702446  3.603  5.6040  6.008  6.4045  7.079
# Eastern Europe   19.0  5.443000  0.379980  4.644  5.2320  5.395  5.7915  5.973
# Asia-Pacific     39.0  5.419974  0.905365  3.794  4.7335  5.269  5.9455  7.469
# Africa           36.0  4.444278  0.558472  3.644  4.0310  4.376  4.7155  5.872
# Europe            1.0  4.096000       NaN  4.096  4.0960  4.096  4.0960  4.096

# %%
WHR_A = WHR[WHR['Region'] == 'Africa']
WHR_WE = WHR[WHR['Region'] == 'Western Europe']
WHR_EE = WHR[WHR['Region'] == 'Eastern Europe']
WHR_LA = WHR[WHR['Region'] == 'Latin America']
WHR_AP = WHR[WHR['Region'] == 'Asia-Pacific']
WHR_NA = WHR[WHR['Region'] == 'North America']

# %%
len(WHR_A[WHR_A['Happiness Score'] > 6])
# Out:
# 0

# %%
print("There are {} countries in Africa that have a happiness score above 6.0 ".format(len(WHR_A[WHR_A['Happiness Score'] > 6])))
# Out:
# There are 0 countries in Africa that have a happiness score above 6.0

# %%
len(WHR_WE[WHR_WE['Happiness Score'] > 6])
# Out:
# 20

# %%
print("There are {} countries in Western Europe that have a happiness score above 6.0 ".format(len(WHR_WE[WHR_WE['Happiness Score'] > 6])))
# Out:
# There are 20 countries in Western Europe that have a happiness score above 6.0

# %%
len(WHR_EE[WHR_EE['Happiness Score'] > 6])
# Out:
# 0

# %%
print("There is {} country in Eastern Europe that has a happiness score above 6.0 ".format(len(WHR_EE[WHR_EE['Happiness Score'] > 6])))
# Out:
# There is 0 country in Eastern Europe that has a happiness score above 6.0

# %%
len(WHR_AP[WHR_AP['Happiness Score'] > 6])
# Out:
# 9

# %%
print("There are {} countries in the Asia Pacific that have a happiness score above 6.0 ".format(len(WHR_AP[WHR_AP['Happiness Score'] > 6])))
# Out:
# There are 9 countries in the Asia Pacific that have a happiness score above 6.0

# %%
len(WHR_LA[WHR_LA['Happiness Score'] > 6])
# Out:
# 13

# %%
print("There are {} countries in the Latin America that have a happiness score above 6.0 ".format(len(WHR_LA[WHR_LA['Happiness Score'] > 6])))
# Out:
# There are 13 countries in the Latin America that have a happiness score above 6.0

# %%
len(WHR_NA[WHR_NA['Happiness Score'] > 6])
# Out:
# 2

# %%
print("There are {} countries in the North America that have a happiness score above 6.0 ".format(len(WHR_NA[WHR_NA['Happiness Score'] > 6])))
# Out:
# There are 2 countries in the North America that have a happiness score above 6.0

# %%
Delta_NA = WHR_NA.max(axis=0)['Happiness Score'] - WHR_NA.min(axis=0)['Happiness Score']
print(Delta_NA)
# Out:
# 0.3680000310000002

# %%
Delta_EE = WHR_EE.max(axis=0)['Happiness Score'] - WHR_EE.min(axis=0)['Happiness Score']
print(Delta_EE)
# Out:
# 1.8769998549999993

# %%
Delta_WE = WHR_WE.max(axis=0)['Happiness Score'] - WHR_WE.min(axis=0)['Happiness Score']
print(Delta_WE)
# Out:
# 2.3420000069999993

# %%
Delta_A = WHR_A.max(axis=0)['Happiness Score'] - WHR_A.min(axis=0)['Happiness Score']
print(Delta_A)
# Out:
# 2.228000164

# %%
Delta_LA = WHR_LA.max(axis=0)['Happiness Score'] - WHR_LA.min(axis=0)['Happiness Score']
print(Delta_LA)
# Out:
# 3.4760000700000004

# %%
Delta_AP = WHR_AP.max(axis=0)['Happiness Score'] - WHR_AP.min(axis=0)['Happiness Score']
print(Delta_AP)
# Out:
# 3.6749999529999995

# %%
++++

3Deltas = {}

# %%
Deltas["North America"] = Delta_NA
Deltas["Eastern Europe"] = Delta_EE
Deltas["Western Europe"] = Delta_WE
Deltas["Africa"] = Delta_A
Deltas["Latin America"] = Delta_LA
Deltas["Asia Pacific"] = Delta_AP

# %%
print("The {} region seems to have the largest range of happiness scores".format(max(Deltas, key=Deltas.get)))
# Out:
# The Asia Pacific region seems to have the largest range of happiness scores

# %% [markdown]
# **C. Bar plot of the Happiness Score**

# %%
WHR['Happiness Score'].head(10).plot(xticks=np.arange(9), kind='barh', figsize= (10, 10))
plt.xlabel("Happiness Score")
plt.title('Happiness Score of the top 10 Countries')
# Out:
# Text(0.5, 1.0, 'Happiness Score of the top 10 Countries')

# %%
WHR[['Economy', 'Family','Health', 'Freedom', 'Generosity', 'Corruption', 'Dystopia']].head(10).plot(kind='barh',
                                                                xticks=np.arange(9), stacked=True, figsize= (10, 10))

plt.xlabel("Happiness Score")
plt.title('Happiness Score of the top 10 Countries')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
WHR_A[['Economy', 'Family','Health', 'Freedom', 'Generosity', 'Corruption', 'Dystopia']].head(10).plot(kind='barh',
                                                                xticks=np.arange(9), stacked=True, figsize= (10, 10))

plt.xlabel("Happiness Score")
plt.title('Happiness Score of the top 10 Countries')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# **D. Histogram of Job Satisfaction**

# %%
WHR['Job Satisfaction'].plot(kind='hist', bins=[ 40, 50, 60, 70, 80, 90, 100], figsize=(10,10))

plt.xlabel("Job Satisfaction in Percent")
plt.title("Distribution of Job Satisfaction")
# Out:
# Text(0.5, 1.0, 'Distribution of Job Satisfaction')

# %% [markdown]
# **E. Pairwise Scatter plots**

# %%
sns.pairplot(data=WHR, kind='reg', height = 5,
                  x_vars=['Happiness Score'],
                  y_vars=['Economy', 'Family','Health', 'Freedom', 'Generosity', 'Corruption', 'Dystopia'])

# %%
sns.pairplot(data=WHR, height = 5, hue='Region',
                  x_vars=['Happiness Score'],
                  y_vars=['Economy', 'Family','Health', 'Freedom', 'Generosity', 'Corruption', 'Dystopia'])-
